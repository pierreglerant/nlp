# %%
import pandas as pd

# %%
train_df = pd.read_csv('C:/Users/ccdeb/Documents/CS/3A/NLP/nlp-cs-2025/train_submission.csv',encoding="utf-8")
#test_df = pd.read_csv('C:/Users/ccdeb/Documents/CS/3A/NLP/nlp-cs-2025/test_without_labels.csv',encoding="utf-8")

train_df = train_df.reset_index()
train = train_df.dropna()
#test = train_df[~train_df['index'].isin(train['index'])]

# %%
train_df.head()
# Out:
#    index   Usage                                               Text Label
# 0      0  Public  َ قَالَ النَّبِيُّ ص إِنِّي أَتَعَجَّبُ مِمَّن...   hau
# 1      1  Public  Filmen forteller historien om Will Hunting  en...   nob
# 2      2  Public  An Arthrostylidium berryi in uska species han ...   wln
# 3      3  Public  Kancunarí enemigosniyquichejta munacuychej  al...   quh
# 4      4  Public  Warmeqa ama yachachichunchu hermanospa tantaku...   quh

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# Séparer les features et labels
X = train['Text']
y = train['Label']

# Transformer le texte en vecteurs TF-IDF
vectorizer = TfidfVectorizer(analyzer='char')  # Utilisation des n-grammes de caractères
X_tfidf = vectorizer.fit_transform(X)

# Diviser les données en train/test
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.2, random_state=42)

# Entraîner un RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)

# Prédire sur l'ensemble de test
y_pred = clf.predict(X_test)

# Évaluer le modèle
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.4f}')
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7305
# c:\Users\ccdeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#          abk       0.99      1.00      1.00       116
#          ace       0.76      0.65      0.70       108
#          ach       0.71      0.55      0.62        22
#          acm       0.34      0.38      0.36        93
#          acr       0.89      0.83      0.86       100
#          ada       0.00      0.00      0.00         1
#          afb       0.33      0.23      0.27        97
#          afr       0.38      0.50      0.43       109
#          ahk       0.98      1.00      0.99        89
#          ajp       0.30      0.41      0.34        79
# ...

# %%
X = train_df[['Text']]
y = train_df[['Label']]

# %%
y.shape,y.dropna().shape
# Out:
# ((190599, 1), (190099, 1))

# %%
X.shape,X.dropna().shape
# Out:
# ((190599, 1), (190599, 1))

# %%
train_df.dropna().shape
# Out:
# (190099, 3)

# %%
pd.DataFrame(X_tfidf)
# Out:
#                                                         0
# 0         (0, 368986)\t0.6526255268800016\n  (0, 284)\...
# 1         (0, 284)\t0.2622972845008596\n  (0, 123365)\...
# 2         (0, 284)\t0.1957567928233424\n  (0, 133100)\...
# 3         (0, 284)\t0.14662301926631235\n  (0, 133100)...
# 4         (0, 284)\t0.1385691241435803\n  (0, 133100)\...
# ...                                                   ...
# 190594    (0, 284)\t0.1188585036672506\n  (0, 133100)\...
# 190595    (0, 284)\t0.08176346559920027\n  (0, 253841)...
# 190596    (0, 284)\t0.2288485584822466\n  (0, 123365)\...
# 190597    (0, 284)\t0.16819135332389767\n  (0, 133100)...
# 190598    (0, 284)\t0.26095954774445457\n  (0, 133100)...
#
# [190599 rows x 1 columns]
